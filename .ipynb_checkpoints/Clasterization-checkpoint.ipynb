# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
from sklearn.preprocessing import LabelEncoder
df['Gender'] = LabelEncoder().fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %%
df = df.drop(['CustomerID'], axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
df.hist(figsize=(10, 10), bins=35)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a13ae7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a085d4c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a153fd588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a14423c18>]],
#       dtype=object)

# %%
sns.pairplot(df, diag_kind="kde")
